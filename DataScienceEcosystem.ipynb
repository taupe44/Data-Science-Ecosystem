# %% [markdown]
# This is my final assigment for the Data science tools course

# %% [markdown]
# ![image.png](attachment:170a2e6a-350f-47bc-8b81-78be51e20da0.png)

# %% [markdown]
# Output :![image.png](attachment:141a5766-e0ea-4e34-a671-ef1c5f80ef0f.png)

# %% [markdown]
# ![image.png](attachment:3cb8250b-8d94-4dba-bc2e-04210bd03b4b.png)

# %% [markdown]
# ![image.png](attachment:08b2576b-eef6-4a6b-ac5e-1f9e1308565c.png)

# %% [markdown]
# ![image.png](attachment:9430534a-d687-4e8d-a7ef-d351b9f640ce.png)

# %% [markdown]
# Output :
#
# ![image.png](attachment:d94a2311-dbcf-4126-be3b-bbf49514a0f5.png)

# %% [markdown]
# ![image.png](attachment:20772d14-1e3e-44ae-9d9f-71117b7828d5.png)

# %% [markdown]
# Output :
#
# ![image.png](attachment:1667c638-84b7-4ebc-8325-6e1db93592d8.png)

# %% [markdown]
# ![image.png](attachment:b7de0271-4c82-481f-b2bc-207dc1015608.png)

# %% [markdown]
# Output :
#
# ![image.png](attachment:e3e37413-e325-4486-8a48-bdfb6ff432b4.png)

# %% [markdown]
# ![image.png](attachment:b48b1940-2c89-499c-b57e-22cc9c47be45.png)

# %% [markdown]
# Output :
#
# ![image.png](attachment:f60dd5a9-ea66-4d4f-895c-30640c843e16.png)

# %% [markdown]
# ![image.png](attachment:86dc1d65-aa4d-453c-a0f2-c9582142719e.png)

# %% [markdown]
# Output:
#
# ![image.png](attachment:7b4052b8-5e10-4081-b581-8e5fbe3eace6.png)

# %% [markdown]
# ![image.png](attachment:03cec26e-5b21-471f-ace7-d9af9fc840de.png)

# %% [markdown]
# ![image.png](attachment:4ded0f8d-b6e8-4228-b8ae-c1367d84a7e9.png)

# %% [markdown]
# ![image.png](attachment:ff018978-cc4d-45a7-9c09-7c395daa24f1.png)

# %% [markdown]
# Output:
#
# ![image.png](attachment:eee18739-5e0b-4ecb-a472-64b1aaf75a1a.png)
